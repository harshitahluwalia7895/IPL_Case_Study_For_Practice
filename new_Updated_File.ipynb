# %% [markdown]
# # Importing the Essential Features needed in this Case Study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading all Files related to IPL

# %%
df_Ball = pd.read_csv('Ball_by_Ball.csv')
df_Matches=pd.read_csv('Match.csv')
df_playermatch=pd.read_csv('Player_Match.csv')
df_player=pd.read_csv('Player.csv')
df_season=pd.read_csv('Season.csv')
df_teams=pd.read_csv('Team.csv')

# %% [markdown]
# # print Column names for all datasets

# %%
print('Ball_by_Ball File ')
print('_'*60)
print(df_Ball.columns.values)
print('-'*60)
print('Match File ')
print('_'*60)
print(df_Matches.columns.values)
print('-'*60)
print('PLayer_Match File ')
print('_'*60)
print(df_playermatch.columns.values)
print('-'*60)
print('Player File ')
print('_'*60)
print(df_player.columns.values)
print('-'*60)
print('Season File ')
print('_'*60)
print(df_season.columns.values)
print('-'*60)
print('Team File ')
print('_'*60)
print(df_teams.columns.values)
print('-'*60)
# Out:
# Ball_by_Ball File
# ____________________________________________________________
# ['Match_Id' 'Innings_Id' 'Over_Id' 'Ball_Id' 'Team_Batting_Id'
#  'Team_Bowling_Id' 'Striker_Id' 'Striker_Batting_Position'
#  'Non_Striker_Id' 'Bowler_Id' 'Batsman_Scored' 'Extra_Type' 'Extra_Runs'
#  'Player_dissimal_Id' 'Dissimal_Type' 'Fielder_Id']
# ------------------------------------------------------------
# Match File
# ____________________________________________________________
# ['Match_Id' 'Match_Date' 'Team_Name_Id' 'Opponent_Team_Id' 'Season_Id'
#  'Venue_Name' 'Toss_Winner_Id' 'Toss_Decision' 'IS_Superover' 'IS_Result'
#  'Is_DuckWorthLewis' 'Win_Type' 'Won_By' 'Match_Winner_Id'
#  'Man_Of_The_Match_Id' 'First_Umpire_Id' 'Second_Umpire_Id' 'City_Name'
#  'Host_Country']
# ------------------------------------------------------------
# PLayer_Match File
# ____________________________________________________________
# ['Match_Id' 'Player_Id' 'Team_Id' 'Is_Keeper' 'Is_Captain']
# ...

# %% [markdown]
# #  Preview Data for all datasets

# %%
print('Ball_by_Ball File ')
print('_'*60)
df_Ball.head()
# Out:
# Ball_by_Ball File
# ____________________________________________________________
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# 4           2                         2               1         14
#
# ...

# %%
print('-'*60)
print('Match File ')
print('_'*60)
df_Matches.head()
# Out:
# ------------------------------------------------------------
# Match File
# ____________________________________________________________
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08             2                 1          1
# 1    335988  19-Apr-08             4                 3          1
# 2    335989  19-Apr-08             6                 5          1
# 3    335990  20-Apr-08             7                 2          1
# 4    335991  20-Apr-08             1                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# ...

# %%
print('-'*60)
print('PLayer_Match File ')
print('_'*60)
df_playermatch.head()
# Out:
# ------------------------------------------------------------
# PLayer_Match File
# ____________________________________________________________
#    Match_Id  Player_Id  Team_Id  Is_Keeper  Is_Captain
# 0    335987          1        1          0           1
# 1    335987          2        1          0           0
# 2    335987          3        1          0           0
# 3    335987          4        1          0           0
# 4    335987          5        1          0           0

# %%
print('_'*60)
df_player.head()
# Out:
# ____________________________________________________________
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
print('Season File ')
print('_'*60)
df_season.head()
# Out:
# Season File
# ____________________________________________________________
#    Season_Id  Season_Year  Orange_Cap_Id  Purple_Cap_Id  Man_of_the_Series_Id
# 0          1         2008            100            102                    32
# 1          2         2009             18             61                    53
# 2          3         2010            133            131                   133
# 3          4         2011            162            194                   162
# 4          5         2012            162            190                   315

# %%
print('Team File ')
print('_'*60)
df_teams.head()
# Out:
# Team File
# ____________________________________________________________
#    Team_Id                    Team_Name Team_Short_Code
# 0        1        Kolkata Knight Riders             KKR
# 1        2  Royal Challengers Bangalore             RCB
# 2        3          Chennai Super Kings             CSK
# 3        4              Kings XI Punjab            KXIP
# 4        5             Rajasthan Royals              RR

# %% [markdown]
# #  print dataset info

# %%
print('_'*80)
print("Ball_by_Ball Dataset")
print('-'*80)
df_Ball.info()
print('_'*80)
print('Matches Dataset')
print('-'*80)
df_Matches.info()
print('_'*80)
print('Player Match info')
print('-'*80)
df_playermatch.info()
print('_'*80)
print('Player Dataset')
print('-'*80)
df_player.info()
print('_'*80)
print('Season Dataset')
print('-'*80)
df_season.info()
print('_'*80)
print('Team Dataset')
df_teams.info()
# Out:
# ________________________________________________________________________________
# Ball_by_Ball Dataset
# --------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136590 entries, 0 to 136589
# Data columns (total 16 columns):
# Match_Id                    136590 non-null int64
# Innings_Id                  136590 non-null int64
# Over_Id                     136590 non-null int64
# Ball_Id                     136590 non-null int64
# Team_Batting_Id             136590 non-null int64
# Team_Bowling_Id             136590 non-null int64
# Striker_Id                  136590 non-null int64
# Striker_Batting_Position    136590 non-null int64
# Non_Striker_Id              136590 non-null int64
# Bowler_Id                   136590 non-null int64
# Batsman_Scored              136590 non-null object
# Extra_Type                  136590 non-null object
# Extra_Runs                  136590 non-null object
# ...

# %% [markdown]
# # Observations from the above Dataset

# %% [markdown]
# # 1.Total 13 teams player till now in app IPL seasons

# %% [markdown]
# # Total 523 personal participated in IPL till now (includes umpires and players)

# %% [markdown]
# # Total 577 matches player till now in IPL

# %%
df_season.apply(np.max)
# Out:
# Season_Id                  9
# Season_Year             2016
# Orange_Cap_Id            187
# Purple_Cap_Id            364
# Man_of_the_Series_Id     334
# dtype: int64

# %% [markdown]
# # From the above observations we can say that-->There are  9 seasons fron 2008 to 2016 including the year  2008 and 2016. There are 334 players who get the achievements of Man of the Series.

# %%
df_teams.apply(np.max)
# Out:
# Team_Id                             13
# Team_Name          Sunrisers Hyderabad
# Team_Short_Code                    SRH
# dtype: object

# %% [markdown]
# # From the above observations we can say that-->THere are 13 Teams in each Season.

# %%
df_Matches.apply(np.max)
# Out:
# Match_Id                         981024
# Match_Date                     9-May-16
# Team_Name_Id                         13
# Opponent_Team_Id                     13
# Season_Id                             9
# Venue_Name             Wankhede Stadium
# Toss_Winner_Id                       13
# Toss_Decision                     field
# IS_Superover                          1
# IS_Result                             1
# Is_DuckWorthLewis                     1
# Win_Type                     by wickets
# Won_By                              144
# Match_Winner_Id                      13
# Man_Of_The_Match_Id                 460
# First_Umpire_Id                     511
# Second_Umpire_Id                    521
# City_Name                 Visakhapatnam
# Host_Country                      U.A.E
# dtype: object

# %% [markdown]
# # From the above observations we can say that-->THere are 13 Teams in each Season. The Last match was played on 9-May-16 and the venue was Wankhede Stadium.

# %%
# plot for match count in each season
sns.countplot(x='Season_Id', data=df_Matches)
plt.show()

# %% [markdown]
# # The above Observation shows that number of matches played in each season.

# %%
# Plot for Matches count at  every stadium
plt.figure(figsize=(12,6))
sns.countplot(y='Venue_Name', data=df_Matches)
plt.yticks(rotation='horizontal')
plt.show()

# %% [markdown]
# # The above Observation States the Stadium Name and the Number of matches played at that Stadium in 9 Seasons(2008-2016 inc. 2008 and 2016)

# %%
# plot for match count in each season
sns.countplot(x='Orange_Cap_Id', data=df_season)

plt.show()
